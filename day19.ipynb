# %% [markdown]
# ## Daniel Barella
# ## 9/19/25

# %% [markdown]
# # 📘 Day 19: Correlation & Covariance
#
# ## Correlation and covariance are tools to measure the relationship between variables in your dataset.

# %% [markdown]
# ## 🧠 Key Concepts
#
# - Covariance
#
#     - Measures how two variables change together.
#
#     - Positive → variables increase together.
#
#     - Negative → one increases while the other decreases.
#
#     - Scale-dependent → hard to compare across variables.
#
# - Correlation
#
#     - Standardized version of covariance.
#
#     - Always between -1 and 1.
#
#     - Easier to interpret:
#
#         - 1 → perfect positive relationship
#
#         - -1 → perfect negative relationship
#
#         - 0 → no linear relationship
#
# - Use case in data science:
#
#     - Identify relationships between features and target variables.
#
#     - Spot multicollinearity (when predictors are too correlated).

# %% [markdown]
# ## 📊 Example with Wine Dataset
#
# We’ll look at correlations between chemical properties and wine quality.

# %% [markdown]
# ### 🔹 Load Data

# %%
import pandas as pd

# Load cleaned dataset
wine = pd.read_csv("wine_clean.csv")
wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %% [markdown]
# ### 🔹 Covariance Matrix

# %%
# Covariance shows raw relationships
wine.cov()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              3.031416         -0.079851     0.227820
# volatile_acidity          -0.079851          0.032062    -0.019272
# citric_acid                0.227820         -0.019272     0.037947
# residual_sugar             0.281756          0.000484     0.039434
# chlorides                  0.007679          0.000517     0.001869
# free_sulfur_dioxide       -2.800921         -0.019674    -0.124252
# total_sulfur_dioxide      -6.482346          0.450426     0.227697
# density                    0.002195          0.000007     0.000134
# pH                        -0.183586          0.006495    -0.016298
# sulphates                  0.054010         -0.007921     0.010328
# alcohol                   -0.114421         -0.038600     0.022815
# quality                    0.174424         -0.056476     0.035612
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %% [markdown]
# ### 🔹 Correlation Matrix

# %%
# Correlation standardizes the covariance
wine.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256131     0.671703
# volatile_acidity          -0.256131          1.000000    -0.552496
# citric_acid                0.671703         -0.552496     1.000000
# residual_sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free_sulfur_dioxide       -0.153794         -0.010504    -0.060978
# total_sulfur_dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %% [markdown]
# ### 🔹 Heatmap for Better Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(wine.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Wine Dataset")
plt.show()

# %% [markdown]
# ### ✅ What to Look For
#
# - Which variables are most correlated with quality?
#
# - Any strong correlations between predictors (multicollinearity risks)?

# %% [markdown]
# ### 🔹 Correlation Matrix

# %%
# Compute correlation matrix
corr_matrix = wine.corr()

# Look at correlations with quality
quality_corr = corr_matrix["quality"].sort_values(ascending=False)
quality_corr
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric_acid             0.226373
# fixed_acidity           0.124052
# residual_sugar          0.013732
# free_sulfur_dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total_sulfur_dioxide   -0.185100
# volatile_acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# ### 🔹 Top Correlations with quality

# %%
# Display top positive & negative correlations with quality
print("Top correlations with wine quality:\n")
print(quality_corr.head(5))   # top positive
print("\n")
print(quality_corr.tail(5))   # top negative
# Out:
# Top correlations with wine quality:
#
# quality          1.000000
# alcohol          0.476166
# sulphates        0.251397
# citric_acid      0.226373
# fixed_acidity    0.124052
# Name: quality, dtype: float64
#
#
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total_sulfur_dioxide   -0.185100
# volatile_acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# ## ✅ Insights to Watch For
#
# - alcohol usually has a positive correlation with quality.
#
# - volatile_acidity often has a negative correlation with quality.
#
# - Weak correlations (< |0.1|) may not be useful predictors.
