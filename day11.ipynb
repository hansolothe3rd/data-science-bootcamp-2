# %% [markdown]
# ## Daniel Barella
# ## 9/14/25

# %% [markdown]
# # Day 11 – Transition & Review
# Welcome to the next phase of the Data Science Bootcamp (Days 11–20)!
# Today’s focus: repo setup, fundamentals review, and a small practice project.

# %% [markdown]
# **Day 11 Goals**
# - Verify GitHub & repo setup ✅
# - Refresh core Python & pandas basics
# - Practice with a small dataset (Iris)
# - Plan learning goals for Days 11–20

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Quick Dataset Practice (Iris Dataset)

# %%
from sklearn.datasets import load_iris

# Load dataset
iris = load_iris(as_frame=True)
df = iris.frame

# Preview
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## 2. Exploratory Analysis

# %%
# Basic info
print(df.info())
print(df.describe())

# Class distribution
df['target'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %% [markdown]
# ## 3. Visualization Practice

# %%
sns.pairplot(df, hue='target')
plt.suptitle("Iris Dataset Pairplot", y=1.02)
plt.show()

# %% [markdown]
# ## 4. Reflection & Next Steps

# %% [markdown]
# ### Reflection
# - Reviewed dataset basics (info, describe, value_counts).
# - Practiced quick visualization with seaborn pairplot.
#
# ### Next Steps
# - Day 12: More in-depth data cleaning workflow
# - Day 13: Feature engineering intro
# - Day 14: Advanced visualization practice
# - Day 15+: Mini project #2 coming soon
